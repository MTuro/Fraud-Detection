# %% [markdown]
# # Exploratory analysis
# Generate the deterministic training data and inspect its class distribution and feature summaries.

# %%
from src.data.collect import generate_transactions

data = generate_transactions()
data.head()

# %%
data['is_fraud'].value_counts(normalize=True).rename('share')

# %%
data.groupby('is_fraud').mean(numeric_only=True).T
